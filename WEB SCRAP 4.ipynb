# %% [markdown]
# # WEB SCRAPPING ASSIGNMENT 4

# %% [markdown]
# ### 1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
#importing required libraries
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings("ignore") 
import time    



from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By


#importing common exceptions
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException

# %%
#fetching chromedriver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
# getting the web page
url= "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
#Creating empty list
Rank = []
Name = []
Artist = []
Upload_date = []
Views = []

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[1]')[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
len(Rank)
# Out:
# 30

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[1]')[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
#Scraping data of video names
try:
    for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[2]')[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')
#Scraping data of artist name
try:
    for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[3]')[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')
#Scraping data of upload dates
try:
    for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[5]')[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')
#Scraping data of views
try:
    for i in driver.find_elements(By.XPATH, '/html/body/div[3]/div[3]/div[5]/div[1]/table[2]/tbody/tr/td[4]')[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#DATA FRAMEING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# ...

# %% [markdown]
# ## 2. Scrape the details team India’s international fixtures from bcci.tv. Url = https://www.bcci.tv/.
# You need to find following details:
#
# A) Match title (I.e. 1st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#fetching chromedriver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#getting the specified url
url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(3)

# %%
#Getting url for international fixture and clicking on it
Options_btn = driver.find_element(By.XPATH,'/html/body/nav/div[1]/button').click()

# %%
#click on international button
internation= driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a').click()
time.sleep(5)

# %%
#Creating empty list
Match_title = []
Series = []
Place = []
Date = []
Time = []

# %%
#Scraping data of match title
for i in driver.find_elements(By.XPATH,'//div[@class="fixture-card-top"]'):
    Match_title.append(i.text)
    
#Scraping data of Place
for i in driver.find_elements(By.XPATH,'//div[@class="fix-place ng-binding ng-scope"]'):
    Place.append(i.text)

# %%
print(len(Place), len(Match_title))
# Out:
# 8 8

# %%
#scraping the date of match
date_tag=driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]')
for i in date_tag:
    date.append(i.text)
len(date)
# Out:
# 8

# %%
#Scraping series of match
for i in driver.find_elements(By.XPATH,'//h5[@class="fix-text"]'):
    Series.append(i.text)

# %%
len(Series)
# Out:
# 8

# %%
#Scraping time of match
for i in driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]'):
    Time.append(i.text)
Time
# Out:
# ['',
#  '12:45 PM IST',
#  '12:45 PM IST',
#  '12:45 PM IST',
#  '7:30 PM IST',
#  '7:30 PM IST',
#  '7:30 PM IST',
#  '7:30 PM IST',
#  '7:30 PM IST']

# %%
Time=Time[1:9]

# %%
len(Time)
# Out:
# 8

# %%
#DATA FRAMEING
BCCI=pd.DataFrame({})
BCCI['Match Title'] = Match_title
BCCI['Series'] = Series
BCCI['Place'] = Place
BCCI['Date'] = date
BCCI['Time'] = Time

# %%
#Printing data frame
BCCI
# Out:
#                                          Match Title  \
# 0  INDIA TOUR OF ZIMBABWE ODI SERIES 2022\n18 AUG...
# 1  INDIA TOUR OF ZIMBABWE ODI SERIES 2022\n20 AUG...
# 2  INDIA TOUR OF ZIMBABWE ODI SERIES 2022\n22 AUG...
# 3            ASIA CUP 2022\n28 AUG 2022\n7:30 PM IST
# 4            ASIA CUP 2022\n31 AUG 2022\n7:30 PM IST
# 5  AUSTRALIA TOUR OF INDIA T20 SERIES 2022\n20 SE...
# 6  AUSTRALIA TOUR OF INDIA T20 SERIES 2022\n23 SE...
# 7  AUSTRALIA TOUR OF INDIA T20 SERIES 2022\n25 SE...
#
#                                    Series  \
# 0
# 1  INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 2
# 3  INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 4
# 5  INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 6
# 7                           ASIA CUP 2022
#
#                                                Place         Date  \
# 0               1st ODI - Harare Sports Club, Harare  18 AUG 2022
# 1               2nd ODI - Harare Sports Club, Harare  20 AUG 2022
# ...

# %% [markdown]
# ## Q3.Scrape the details of selenium exception from guru99.com. Url = https://www.guru99.com/
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#fetching chromedriver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#getting the specified url
url = "https://www.guru99.com/"
driver.get(url)
time.sleep(3)

# %%
#Going to search bar and searching for selenium exception
ser_bar = driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")
ser_bar.send_keys("selenium exception handling")
ser_but = driver.find_element(By.XPATH,"/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[2]/button").click()
time.sleep(3)

# %%
#Scraping names of exceptions
Name = []
for i in driver.find_elements(By.XPATH,'//div[@class="gs-title"]'):
    Name.append(i.text)
    
#Scraping descriptions of exceptions  
Description = []
for i in driver.find_elements(By.XPATH,'//div[@class="gs-bidi-start-align gs-snippet"]'):
    Description.append(i.text)

# %%
#DATA FRAMEING
Guru=pd.DataFrame({})
Guru['Name of Exception'] = Name
Guru['Description of Exception'] = Description

# %%
#Printing data frame
Guru
# Out:
#                                     Name of Exception  \
# 0   Selenium Exception Handling (Common Exceptions...
# 1   How to Handle SSL Certificate in Selenium WebD...
# 2       Try Catch in Java: Exception Handling Example
# 3   Python Exception Handling: try, catch, finally...
# 4   C++ Exception Handling: Try, Catch, throw Example
# 5   Oracle PL/SQL Exception Handling: Examples to ...
# 6   Exception Handling in VB.Net: Try & Catch Hand...
# 7   PHP Try Catch Example: Exception & Error Handl...
# 8           JSP Exception Handling: Error Page in JSP
# 9   Selenium Alert & Popup Window Handling: How to...
# 10
#
#                              Description of Exception
# 0   23-Jul-2022 ... Common Exceptions in Selenium ...
# 1   25-Jun-2022 ... For handling SSL certificate e...
# 2   09-Jul-2022 ... All these errors are highlight...
# 3   09-Jul-2022 ... In this Python exceptional han...
# 4   09-Jul-2022 ... Next, the exception handler wi...
# ...

# %% [markdown]
# ## Q4.Scrape the details of State-wise GDP of India from statisticstime.com. Url = http://statisticstimes.com/
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP
#
# D) GSDP
#
# E) Share
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code

# %%
#fetching chromedriver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#getting the specified url
url = "http://statisticstimes.com/"
driver.get(url)
time.sleep(3)

# %%
#Clicking on economy section
economy_tag=driver.find_element(By.XPATH, '/html/body/div[2]/div[1]/div[2]/div[2]/button').click()

# %%
#clicking to india button
India_tag=driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]').click()

# %%
# find India GDP and click on it
Ind_gdp=driver.find_element(By.XPATH, '/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
Ind_gdp.click()

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
rank_tag=driver.find_elements(By.XPATH, '//td[@class="data1"]')
for i in rank_tag[:33]:
    Rank.append(i.text)
len(Rank)
# Out:
# 33

# %%
state_tag=driver.find_elements(By.XPATH, '//td[@class="name"]')
for i in state_tag[:33]:
    State.append(i.text)
len(State)
# Out:
# 33

# %%
# Scraping data of GSDP at current price (19-20)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[3]'):
    GSDP_1.append(i.text)
len (GSDP_1)
# Out:
# 33

# %%
#Scraping data of rank
for i in driver.find_elements(By.XPATH, '//td[@class="data1"]'):
    Rank.append(i.text)

    
#Scraping data of state name
for i in driver.find_elements(By.XPATH, '//td[@class="name"]'):
    State.append(i.text)

    
# Scraping data of GSDP at current price (19-20)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[3]'):
    GSDP_1.append(i.text)

    
#Scraping data of GSDP at current price (18-19)
for i in driver.find_elements(By.XPATH,'//td[@class="data sorting_1"]'):
    GSDP_2.append(i.text)

    
#Scraping data of Share(18-19)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[5]'):
    Share.append(i.text)

    
#Scraping data of GDP($ billion)
for i in driver.find_elements(By.XPATH,'/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr/td[6]'):
    GDP.append(i.text)

# %%
#DATA FRAMEING
StatisticsTime=pd.DataFrame({})
StatisticsTime['Rank'] = Rank
StatisticsTime['State'] = State
StatisticsTime['GSDP at current price (19-20)'] = GSDP_1
StatisticsTime['GSDP at current price (18-19)'] = GSDP_2
StatisticsTime['Share(18-19)'] = Share
StatisticsTime['GDP($ billion)'] = GDP

# %%
#Printing the data frame
StatisticsTime
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# 5     6                West Bengal                     1,253,832
# 6     7                  Rajasthan                     1,020,989
# 7     8             Andhra Pradesh                       972,782
# 8     9                  Telangana                       969,604
# 9    10             Madhya Pradesh                       906,672
# 10   11                     Kerala                             -
# 11   12                      Delhi                       856,112
# 12   13                    Haryana                       831,610
# ...

# %%
driver.close()

# %% [markdown]
# ## Q5.Scrape the details of trending repositories on Github.com. Url = https://github.com/
# You have to find the following details: A) Repository title
#
# B) Repository description C) Contributors count
#
# D) Language used

# %%
#fetching chromedriver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
# getting url
url = 'https://github.com/'
driver.get(url)

# %%
#clicking on menu
menu=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/button').click()

# %%
#clicking on explore button
explore=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[2]/nav/ul/li[4]').click()

# %%
#clicking ontrending button
trending=driver.find_element(By.XPATH, '/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a').click()

# %%
#scrapping required data
title=[]
t_tag=driver.find_elements(By.XPATH,'/html/body/div[4]/main/div[3]/div/div[2]/article/h1/a')
for i in t_tag:
    title.append(i.text)

# %%
descrption=[]
descrp_tag=driver.find_elements(By.XPATH,'/html/body/div[4]/main/div[3]/div/div[2]/article/p')
for i in descrp_tag:
    descrption.append(i.text)

# %%
language=[]
lang_tag= driver.find_elements(By.XPATH,'/html/body/div[4]/main/div[3]/div/div[2]/article/div[2]/span[1]')
for i in lang_tag:
    language.append(i.text)

# %%
# contributors
url=[]
url_tag=driver.find_elements(By.XPATH, '/html/body/div[4]/main/div[3]/div/div[2]/article/h1/a')
for i in url_tag:
    url.append(i.get_attribute('href'))
len(url)
# Out:
# 25

# %%
contributor=[]
for i in range(0,len(url)):
    driver.get(url[i])
    time.sleep(10)
    
    try: 
        conti_tag=driver.find_elements(By.XPATH,'//a[@class="Link--primary no-underline"]')
        for count in conti_tag:
            contributor.append(count.text)
    except None:
        contributor.append('N/A')
len(contributor)
# Out:
# 104

# %%
contri= list(filter(lambda k: 'Contributors ' in k, contributor))
contri
# Out:
# ['Contributors 3',
#  'Contributors 4',
#  'Contributors 300',
#  'Contributors 7',
#  'Contributors 18',
#  'Contributors 827',
#  'Contributors 4',
#  'Contributors 16',
#  'Contributors 466',
#  'Contributors 2',
#  'Contributors 2',
#  'Contributors 76',
#  'Contributors 26',
#  'Contributors 260',
#  'Contributors 100',
#  'Contributors 281',
#  'Contributors 2,183',
#  'Contributors 224',
#  'Contributors 5,000+',
#  'Contributors 2',
#  'Contributors 679',
#  'Contributors 364',
#  'Contributors 365']

# %%
len(contri)
# Out:
# 23

# %%
len(title), len(descrption),len(language),len(contri)
# Out:
# (25, 23, 25, 23)

# %%
title=title[0:23]
len(title)
# Out:
# 23

# %%
language = language[0:23]
len(language)
# Out:
# 23

# %%
# Preparing data frame.

repository= pd.DataFrame({'Repository Title':title, 'Repository Description': descrption,
                         'Language':language,'Contributors': contri})
print(" Trending Repository in github\n")
repository
# Out:
#  Trending Repository in github
#                                 Repository Title  \
# 0                     CompVis / stable-diffusion
# 1                        ange-yaghi / engine-sim
# 2                              withastro / astro
# 3                    craftzdog / dotfiles-public
# 4                        dragonflydb / dragonfly
# 5                         TheAlgorithms / Python
# 6                     microsoft / fluentui-emoji
# 7                             ocsf / ocsf-schema
# 8                             Anuken / Mindustry
# 9                        Baiyuetribe / paper2gui
# 10  Unity-Technologies / com.unity.demoteam.hair
# 11                    redballoonsecurity / ofrak
# 12                                 novuhq / novu
# 13                             MatrixTM / MHDDoS
# 14                     datahub-project / datahub
# 15                  leonardomso / 33-js-concepts
# 16                               dotnet / efcore
# ...

# %% [markdown]
# ## Q6: Scrape the details of top 100 songs on billboard.com. Url=https://www.billboard.com/. You have to find the following details:
# A)Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board

# %%
#importing required libraries
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings("ignore") 
import time    



from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By


#importing common exceptions
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException

# %%
#fetching chromedriver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#Getting url
url = 'https://www.billboard.com/'
driver.get(url)

# %%
#clicking on menu
menu=driver.find_element(By.XPATH, '/html/body/div[3]/header/div[1]/div/div/div[1]/button').click()

# %%
#click on Hot 100 
hot_100_tag=driver.find_element(By.XPATH,'/html/body/div[3]/div[6]/div/div/div/ul/li[1]/ul/li[2]/a').click()

# %%
# scrapping song detail
#web element for song title
xyz_tag=driver.find_elements(By.ID, "title-of-a-story")
xyz=[]
for i in xyz_tag:
    xyz.append(i.text)
len(xyz)
# Out:
# 419

# %%
# scraping 100 sons out of it
song = list(filter (lambda k: k!= '', xyz))
song=song[:100]

# %%
# scrapping all details
artist=[]
art_tag= driver.find_elements(By.XPATH,'/html/body/div[3]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[1]/span')
for i in art_tag:
    artist.append(i.text)
    

last_rank=[]
last_tag=driver.find_elements(By.XPATH, '/html/body/div[3]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[7]/ul/li[3]')
for i in last_tag:
    last_rank.append(i.text)

peak_rank=[]
peak_tag=driver.find_elements(By.XPATH,'/html/body/div[3]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[7]/ul/li[4]/span')
for i in peak_tag:
    peak_rank.append(i.text)

weeks_on=[]
w_board_tag=driver.find_elements(By.XPATH, '/html/body/div[3]/main/div[2]/div[3]/div/div/div/div[2]/div/ul/li[4]/ul/li[7]/ul/li[5]/span')
for i in w_board_tag:
    weeks_on.append(i.text)

# %%
# Make data frame of hot 100 from https://www.billboard.com/
Hot_100 = pd.DataFrame({})
Hot_100['Song_name']= song
Hot_100['Artist_name'] = artist
Hot_100['Last_week_rank'] = last_rank 
Hot_100['Peak_rank'] = peak_rank
Hot_100['Weeks_on_chart'] = weeks_on 
Hot_100
# Out:
#                                  Song_name                    Artist_name  \
# 0                            Break My Soul                        Beyonce
# 1                          About Damn Time                          Lizzo
# 2                                As It Was                   Harry Styles
# 3   Running Up That Hill (A Deal With God)                      Kate Bush
# 4                               Wait For U  Future Featuring Drake & Tems
# ..                                     ...                            ...
# 95                       Until I Found You                Stephen Sanchez
# 96                               Un Ratito                      Bad Bunny
# 97              Best Thing Since Backroads                      Jake Owen
# 98                            La Corriente          Bad Bunny & Tony Dize
# 99            Bzrp Music Sessions, Vol. 52             Bizarrap & Quevedo
#
#    Last_week_rank Peak_rank Weeks_on_chart
# 0
# 1
# 2
# 3
# 4
# ...

# %%
driver.close()

# %% [markdown]
# ## 7. Scrape the details of Data science recruiters from naukri.com. Url = https://www.naukri.com/ You have to find the following details:
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location

# %%
#fetching driver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#getting the specified url
url = "https://www.naukri.com/hr-recruiters-consultants"
driver.get(url)
time.sleep(3)

# %%
#Fetching search button,bar xpath and clicking on it
#searching for web elements  for search job bar usng id
search_jobs = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/div/div[1]/div[1]/div[2]/input')
search_jobs.send_keys("Data Science")

# %%
search_btn = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[1]/div[1]/form/div[1]/button').click()

# %%
#Creating empty list
Name = []
Designation = []
Company = []
Skills = []
Location = []

# %%
#Scraping data of Names
for i in driver.find_elements(By.XPATH,'//a[@class="ellipsis"]/span[1]')[:48]:
    Name.append(i.text)
time.sleep(5)


#Scraping data of Designation
for i in driver.find_elements(By.XPATH, '//span[@class="ellipsis clr"]')[:48]:
    Designation.append(i.text)
time.sleep(5)

#Scraping data of company name
for i in driver.find_elements(By.XPATH, '//a[2][@class="ellipsis"]')[:48]:
    Company.append(i.text)
time.sleep(5)
    
#scraping data of Skills 
for i in driver.find_elements(By.XPATH,'//div[@class="hireSec highlightable"]')[:48]:
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
    time.sleep(5)

#Scraping data of locations
for i in driver.find_elements(By.XPATH,'//small[@class="ellipsis"]')[:48]:
    Location.append(i.text)
time.sleep(5)

# %%
Location= Location[0:48]

# %%
#DATA FRAMEING
Naukri=pd.DataFrame({})
Naukri['Name'] = Name
Naukri['Designation'] = Designation
Naukri['Company'] = Company
Naukri['Skills'] = Skills
Naukri['Location'] = Location

# %%
#Printing data frame
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                             Vaishnavi Kudalkar
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()

# %% [markdown]
# ## 8. Scrape the details of Highest selling novels. Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/ You have to find the following details:
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
#fetching driver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#getting the specified url
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
driver.get(url)
time.sleep(3)

# %%
Book_name=[]
Author=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

# %%
#scraping data of book names
for i in driver.find_elements(By.XPATH, '/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[2]'):
    Book_name.append(i.text)


(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[6]')


    
#Scraping data of author names
for i in driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[3]'):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author.append(i.text)
    except NoSuchElementException:
        Author.append('-')
time.sleep(1)


#Scraping data of volumes sold
for i in driver.find_elements(By.XPATH, '/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[4]'):
    Volumes_sold.append(i.text)

    
#Scraping data of publisher names
for i in driver.find_elements(By.XPATH, '/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[5]'):
    Publisher.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,'/html/body/div/div[2]/div[2]/div/div[2]/div/table/tbody/tr/td[6]'):
    Genre.append(i.text)

# %%
#DATA FRAMEING
Novel=pd.DataFrame({})
Novel['Book Name'] = Book_name
Novel['Author'] = Author
Novel['Volume sold'] = Volumes_sold
Novel['Publisher'] = Publisher
Novel['Genre'] = Genre

# %%
#Printing data frame
Novel
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# ## 9. Scrape the details most watched tv series of all time from imdb.com. Url = https://www.imdb.com/list/ls095964455/ You have to find the following details:
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
#fetching driver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#getting the specified url
url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(3)

# %%
#Creating empty lists.
Genre = []
Run_time = []
Ratings = []
votes = []

# %%
#Scraping data of Names & Year
Name=[]
Year_span=[]
tv_tag=driver.find_elements(By.XPATH, '//h3[@class="lister-item-header"]')
for i in tv_tag:
    Name.append((i.text).split('(')[0])
    Year_span.append((i.text).split('(')[1])

    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]/span[5]'):
    Genre.append(i.text)

    
#Scraping data of Run time
for i in driver.find_elements(By.XPATH, '//p[@class="text-muted text-small"]/span[3]'):
    Run_time.append(i.text)

    
#Scraping data of Ratings
for i in driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]/span[2]'):
    Ratings.append(i.text)

    
#Scraping data of votes
votes=[]
temp=[]
vote_tag=driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"]/span[2]')
for i in vote_tag:
    temp.append(i.text)
for i in range(1,len(temp),2):
    votes.append(temp[i])

# %%
Name = Name[0:100]
Year_span =Year_span [0:100]
Genre =Genre[0:100]
Run_time =Run_time[0:100]
Ratings=Ratings[0:100]
votes=votes[0:100]

# %%
#DATA FRAMEING
IMDB=pd.DataFrame({})
IMDB['Name'] = Name
IMDB['Year Span'] = Year_span
IMDB['Genre'] = Genre
IMDB['Run Time'] = Run_time
IMDB['Ratings'] = Ratings
IMDB['Votes'] = votes

# %%
#Printing data frame
IMDB
# Out:
#                                    Name   Year Span                     Genre  \
# 0                   1. Game of Thrones   2011–2019)  Action, Adventure, Drama
# 1                   2. Stranger Things      2016– )    Drama, Fantasy, Horror
# 2                  3. The Walking Dead   2010–2022)   Drama, Horror, Thriller
# 3                    4. 13 Reasons Why   2017–2020)  Drama, Mystery, Thriller
# 4                           5. The 100   2014–2020)    Drama, Mystery, Sci-Fi
# ..                                  ...         ...                       ...
# 95                           96. Reign   2013–2017)                     Drama
# 96  97. A Series of Unfortunate Events   2017–2019)  Adventure, Comedy, Drama
# 97                  98. Criminal Minds   2005–2020)     Crime, Drama, Mystery
# 98           99. Scream: The TV Series   2015–2019)      Comedy, Crime, Drama
# 99     100. The Haunting of Hill House        2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# ...

# %%
driver.close()

# %% [markdown]
# ## 10. Details of Datasets from UCI machine learning repositories. Url = https://archive.ics.uci.edu/ You have to find the following details:
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year

# %%
#fetching driver
driver = webdriver.Chrome(r'C:\Users\nidsi\Downloads\chromedriver_win32\chromedriver.exe')

# %%
#getting the specified url
url = "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(3)

# %%
#fetching the required tags and looping it
view_all_tag=driver.find_element(By.XPATH, '/html/body/table[2]/tbody/tr/td/span/b/a')
view_all_tag.click()

# %%
dataset=[]
datatype=[]
Task=[]
attr_type=[]
instances=[]
attributes=[]
year=[]

# %%
#scrapping details using ty except

try:                              
    for i in range(1):
        for j in driver.find_elements(By.XPATH,'//p[@class="normal"]/b'):
            dataset.append(j.text)
except:
    dataset.append("-")


try:
    for i in range(1):
        for j in driver.find_elements(By.XPATH, '/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]/p'):
            datatype.append(j.text)
except:
    datatype.append("-")


try:
    for i in range(1):
        for j in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]/p'):
            Task.append(j.text)
except:
    Task.append("-")


try:
    for i in range(1):
        for j in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]/p'):
            attr_type.append(j.text)
except:
    attr_type.append("-")
    

try:
    for i in range(1):
        for j in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]/p'):
            instances.append(j.text)
except:
    instances.append("-")
    

try:
    for i in range(1):
        for j in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]/p'):
            attributes.append(j.text)
except:
    attributes.append("-")
    

try:
    for i in range(1):
        for j in driver.find_elements(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]/p'):
            year.append(j.text)
except:
    year.append("-")

# %%
#DATA FRAMEING
UCIML=pd.DataFrame({})
UCIML['Dataset name'] = dataset
UCIML['Data type'] = datatype
UCIML['Task'] = Task
UCIML['Attribute type'] = attr_type
UCIML['No of instances'] = instances
UCIML['No of attribute'] = attributes
UCIML['Year'] = year

# %%
UCIML
# Out:
#                                           Dataset name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data type                  Task  \
# 0                    Data Types          Default Task
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                 Multivariate        Classification
# ...

# %%
driver.close()
